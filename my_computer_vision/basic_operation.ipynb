# %%
"""
1. read image and show
2. show the r, g, b
3. show the min(r,g,b)

"""

# %%
# %matplotlib inline
import PIL
import numpy as np
import matplotlib.pyplot as plt
img = PIL.Image.open("test.jpg")
plt.imshow(img)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x335 at 0x7F8B4A2A0CF8>

# %%
data = np.asarray(img)

# %%
data[:,:,1]
plt.imshow(data[:,:,0],cmap=plt.cm.gray)

# %%
plt.imshow(data[:,:,1],cmap=plt.cm.gray)

# %%
plt.imshow(data[:,:,2],cmap=plt.cm.gray)

# %%
m = np.amin(data, axis=2)   # Minum along the first axis
plt.imshow(m,cmap=plt.cm.gray)
